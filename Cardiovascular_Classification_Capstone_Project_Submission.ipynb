# %% [markdown]
# <a href="https://colab.research.google.com/github/Vrishali04/Cardiovascular_Risk_Prediction_Classification_Capstone_Project2/blob/main/Cardiovascular_Classification_Capstone_Project_Submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Cardiovascular Classification Capstone Project

# %% [markdown]
# ##### **Project Type**    - Cardiovascular_risk_prediction_classification_capstone_project
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - <b>VRISHALI LATE</b>
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
# this project

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/Vrishali04/Cardiovascular_Risk_Prediction_Classification_Capstone_Project2

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# To performe mathematical operations
import numpy as np

# To load data from file
import pandas as pd

# # To visualize the data and get more insight from the data
import matplotlib.pyplot as plt
import seaborn as sns

# To avoid the warning that aren't necessarily exceptions
import warnings
warnings.filterwarnings('ignore')

# Sets the backend of seaborn to the 'inline' backend
sns.set()
# Sets the backend of matplotlib to the 'inline' backend
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Almabetter_Capstone_Projects/Cardiovascular Classification Capstone Project/data_cardiovascular_risk.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
# Printing the last five elements from dataset using pandas tail

df.tail()
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3385                0             0         0    261.0  123.5   79.0  29.28
# 3386                0             0         0    199.0  102.0   56.0  21.96
# 3387                0             1         0    352.0  164.0  119.0  28.92
# 3388                0             1         0    191.0  167.0  105.0  23.01
# 3389                0             0         0    288.0  124.0   77.0  29.88
#
#       heartRate  glucose  TenYearCHD
# 3385       70.0    103.0           0
# 3386       80.0     84.0           0
# 3387       73.0     72.0           1
# 3388       80.0     85.0           0
# 3389       79.0     92.0           0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Printing the columns presesnt in dataset

print('Columns in our data:')

df.columns
# Out:
# Columns in our data:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    id  age  education  sex  is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 1   1   36        4.0    1           0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
#
#    TenYearCHD
# 1           0

# %%
# Extracting from pandas shape method to get the shape of our dataset

print('Shape of our dataset is: ')
df.shape
# Out:
# Shape of our dataset is:
# (3390, 17)

# %%
print('Count of Rows:',df.shape[0])
print('Count of Columns:',df.shape[1])
# Out:
# Count of Rows: 3390
# Count of Columns: 17

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
#  16  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 450.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df[df.duplicated()].shape
# Out:
# (0, 17)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                   0
# age                  0
# education           87
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
# Visualizing the missing values
df.isnull().sum().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# There is no duplicate data
#
# There are missing values in **education**,**cigsPerDay**,**BPMeds**,**totChol**,**BMI**,**heartRate** and **glucose** columns

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# id                 0
# age                0
# education          0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  2927.000000  2927.000000  2927.000000  2927.000000  2927.000000
# mean   1692.869833    49.507345     1.965494     9.112743     0.030065
# std     986.025198     8.597191     1.017199    11.882784     0.170795
# min       1.000000    32.000000     1.000000     0.000000     0.000000
# 25%     836.500000    42.000000     1.000000     0.000000     0.000000
# 50%    1689.000000    49.000000     2.000000     0.000000     0.000000
# 75%    2547.500000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol        sysBP  \
# count      2927.000000   2927.000000  2927.000000  2927.000000  2927.000000
# mean          0.006150      0.314315     0.026990   237.129142   132.626409
# std           0.078192      0.464322     0.162082    44.613282    22.326197
# min           0.000000      0.000000     0.000000   113.000000    83.500000
# 25%           0.000000      0.000000     0.000000   206.000000   117.000000
# 50%           0.000000      0.000000     0.000000   234.000000   128.500000
# 75%           0.000000      1.000000     0.000000   264.000000   144.000000
# max           1.000000      1.000000     1.000000   600.000000   295.000000
#
#              diaBP          BMI    heartRate      glucose   TenYearCHD
# count  2927.000000  2927.000000  2927.000000  2927.000000  2927.000000
# mean     82.906218    25.797041    75.888282    81.934404     0.151691
# std      12.078873     4.130376    11.971207    24.106943     0.358783
# min      48.000000    15.960000    45.000000    40.000000     0.000000
# 25%      74.500000    23.030000    68.000000    71.000000     0.000000
# 50%      82.000000    25.380000    75.000000    78.000000     0.000000
# 75%      90.000000    28.040000    83.000000    87.000000     0.000000
# max     142.500000    56.800000   143.000000   394.000000     1.000000

# %%
# For categorical columns
df.describe(include='object')
# Out:
#          sex is_smoking
# count   2927       2927
# unique     2          2
# top        F         NO
# freq    1620       1480

# %%
# Selecting the categorical column only
cat_cols = df.select_dtypes(include = 'object').columns
print('count of categorical columns :',len(cat_cols))
# Out:
# count of categorical columns : 2

# %%
# Selecting the numerical column only
num_cols = df.select_dtypes(include = 'number').columns
print('count of Numerical columns :',len(num_cols))
# Out:
# count of Numerical columns : 15

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
# count of categorical columns : 2
#
# count of Numerical columns : 15

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for i in df.columns:
  print(i, df[i].nunique())
# Out:
# id 2927
# age 39
# education 4
# sex 2
# is_smoking 2
# cigsPerDay 31
# BPMeds 2
# prevalentStroke 2
# prevalentHyp 2
# diabetes 2
# totChol 232
# sysBP 222
# diaBP 138
# BMI 1195
# heartRate 67
# glucose 127
# TenYearCHD 2

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.hist(df['age'], bins=10, color='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>The chart chosen is a histogram with 10 bins, which is used to display the frequency distribution of a continuous variable such as age. This chart helps to visualize the age distribution of the data in a clear and concise manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# * From the plot, we can see that most of the individuals in the data set are between the ages of 40 and 70. There is a relatively lower number of individuals in the age groups of 20-40 and 70-90.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>As for whether the insights gained from this chart will help create a positive business impact, it would depend on the context and purpose of the analysis. For example, if the business is a healthcare company trying to understand the age distribution of its patient base, then the insights gained from this chart could potentially help inform their marketing and outreach strategies to better serve the needs of their patients.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

plt.hist(df['cigsPerDay'], bins=10, color='blue')
plt.xlabel('Cigarettes per Day')
plt.ylabel('Frequency')
plt.title('Cigarettes per Day Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>The chart chosen is a histogram with 10 bins, which is used to display the frequency distribution of a continuous variable such as the number of cigarettes smoked per day. This chart helps to visualize the distribution of smoking behavior in a clear and concise manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>The histogram of cigsPerDay shows that the majority of individuals in the data set either do not smoke or smoke less than 10 cigarettes per day.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>As for whether the insights gained from this chart will help create a positive business impact, it would depend on the context and purpose of the analysis. For example, if the business is a healthcare company trying to understand the smoking behavior of their patients, then the insights gained from this chart could potentially help inform their smoking cessation programs and other interventions to reduce the negative health effects of smoking.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.boxplot(df['sysBP'], vert=False)
plt.xlabel('Systolic Blood Pressure')
plt.title('Systolic Blood Pressure Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>The chart chosen is a boxplot, which is used to display the distribution of a continuous variable such as systolic blood pressure. This chart helps to visualize the center, spread, and skewness of the data in a clear and concise manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>The median systolic blood pressure value is around 135 mmHg.
# *The lower and upper quartiles are around 120 and 150 mmHg, respectively, meaning that 50% of the values in the column lie between these values.
# *There are potential outliers present in the distribution, indicated by the dots beyond the whiskers of the plot. These values could be further investigated to determine if they are true outliers or if they represent valid data points.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>As for whether the insights gained from this chart will help create a positive business impact, it would depend on the context and purpose of the analysis. For example, if the business is a healthcare company trying to understand the distribution of blood pressure readings among their patients, then the insights gained from this chart could potentially help inform their treatment plans and interventions to reduce the risk of cardiovascular disease and other related conditions.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

sns.violinplot(df['BMI'], color='purple')
plt.xlabel('Body Mass Index')
plt.title('Body Mass Index Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>The chart chosen is a violin plot, which is a combination of a boxplot and a kernel density plot. It is used to visualize the distribution of a continuous variable such as body mass index (BMI) in a clear and concise manner. The shape of the violin plot indicates the distribution of the data, while the width of the plot indicates the density of the data at that particular value. This chart is useful for comparing the distribution of a variable across different categories or groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>The distribution of BMI values is roughly symmetrical, with a single mode at around 25.
#
# There are some values on the higher end of the distribution that are likely to represent higher BMIs.
#
# There may be multiple modes in the distribution, as indicated by the multiple peaks in the violin plot. This could suggest the presence of different subgroups with different BMI values within the data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>The insights gained from this chart could potentially help create a positive business impact if the business is in the healthcare or fitness industry. For example, if the business is a weight loss program, the insights gained from this chart could help them understand the distribution of BMI among their clients and develop targeted interventions to help clients achieve a healthy BMI.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

sns.barplot(x='sex', y='TenYearCHD', data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>The chart chosen is a bar plot, which is used to display the relationship between a categorical variable such as sex and a continuous variable such as the 10-year risk of developing coronary heart disease (TenYearCHD). This chart helps to visualize the differences in the mean or median TenYearCHD risk between different groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>The bar plot shows the relationship between the 'sex' and 'TenYearCHD' variables.
# From the plot, it can be observed that males have a higher likelihood of having a heart disease in the next 10 years compared to females.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>As for whether the insights gained from this chart will help create a positive business impact, it would depend on the context and purpose of the analysis. For example, if the business is a healthcare company trying to understand the gender differences in the risk of developing coronary heart disease, then the insights gained from this chart could potentially help inform their marketing strategies, product development, and interventions to reduce the risk of coronary heart disease among their clients.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Plot a scatterplot of totChol vs age
sns.scatterplot(x="age", y="totChol", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>The chart chosen is a scatterplot, which is used to display the relationship between two continuous variables such as age and total cholesterol (totChol). This chart helps to visualize the direction and strength of the relationship between the two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>The scatter plot indicates that as the age of an individual increases, their total cholesterol levels also tend to increase. This relationship appears to be positive and relatively linear, meaning that as one variable increases, the other tends to increase as well. This could indicate that age and total cholesterol levels are related and that older individuals may be at a higher risk of high cholesterol and its associated health problems.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>The chart chosen is a scatterplot, which is used to display the relationship between two continuous variables such as age and total cholesterol (totChol). This chart helps to visualize the direction and strength of the relationship between the two variables.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Plot a line plot of sysBP vs age
sns.lineplot(x="age", y="sysBP", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>I picked a line plot because it allows me to visualize the trend in the relationship between two continuous variables, age and systolic blood pressure (sysBP). By plotting age on the x-axis and sysBP on the y-axis, I can see how sysBP changes as age increases or decreases.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>The age of an individual increases, their systolic blood pressure also tends to increase. This relationship appears to be positive and relatively linear, meaning that as one variable increases, the other tends to increase as well. This could indicate that age and systolic blood pressure are related and that older individuals may be at a higher risk of high blood pressure and its associated health problems.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>The gained insights from this plot can potentially help create a positive business impact by informing healthcare professionals or organizations about the relationship between age and systolic blood pressure, which can help in the prevention and management of cardiovascular diseases. For instance, they can use this information to develop targeted health interventions or screening programs for people at risk of high blood pressure or related health conditions.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Plot a bar plot of education vs TenYearCHD
sns.barplot(x="education", y="TenYearCHD", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>I picked a bar plot because it allows me to visualize the relationship between a categorical variable, education, and a binary outcome variable, TenYearCHD. By plotting education on the x-axis and TenYearCHD on the y-axis, I can compare the proportions of people with and without CHD across different education levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>The bar plot shows the average value of the TenYearCHD variable for different levels of education. From the plot, it appears that as the education level increases, the average value of TenYearCHD decreases. This indicates that higher levels of education might be associated with a lower risk of having a heart disease event within the next 10 years. However, it is important to keep in mind that correlation does not necessarily imply causation, and other factors such as income, lifestyle, and access to healthcare could also be contributing to this relationship.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>The gained insights from this plot can potentially help create a positive business impact by informing healthcare professionals or organizations about the relationship between education and CHD risk, which can aid in the development of targeted interventions and health education programs for individuals with lower education levels. This could ultimately lead to a reduction in CHD prevalence and related healthcare costs.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# Plot a box plot of glucose vs is_smoking
sns.boxplot(x="is_smoking", y="glucose", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>I picked a box plot because it allows me to visualize the distribution of a continuous variable, glucose, across two levels of a binary variable, is_smoking. By plotting is_smoking on the x-axis and glucose on the y-axis, I can compare the distribution of glucose levels between smokers and non-smokers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>Median, quartiles, and outliers for each group. It appears that the median glucose level is slightly higher for people who smoke compared to those who do not smoke. However, the overall range of glucose levels is similar for both groups. This suggests that there is no strong association between smoking and glucose levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>The gained insights from this plot can potentially help create a positive business impact by providing healthcare professionals or organizations with information about the potential effect of smoking on glucose levels. This information can be used to develop targeted interventions or health education programs to help smokers quit smoking and improve their glucose levels, which can ultimately lead to better overall health outcomes.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Plot a violin plot of BMI vs prevalentStroke
sns.violinplot(x="prevalentStroke", y="BMI", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>I picked a violin plot because it allows me to visualize the distribution and density of a continuous variable, BMI, across two levels of a binary variable, prevalentStroke. By plotting prevalentStroke on the x-axis and BMI on the y-axis, I can compare the distribution of BMI levels between individuals with and without a prevalent stroke.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>For those individuals who have a prevalent stroke, the distribution of their BMI values is more spread out and is centered around a higher value compared to those who do not have a prevalent stroke.
# The majority of individuals with a prevalent stroke have a higher BMI compared to those who do not have a prevalent stroke.
# Some individuals with a prevalent stroke have a BMI value that falls in the lower range, indicating that not all individuals with a prevalent stroke have a higher BMI.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
#
# <b>The gained insights from this plot can potentially help create a positive business impact by providing healthcare professionals or organizations with information about the potential effect of stroke on BMI levels. This information can be used to develop targeted interventions or health education programs to help individuals with a history of stroke maintain a healthy BMI, which can improve their overall health outcomes and reduce their risk of stroke recurrence.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Plot a swarm plot of heartRate vs diabetes
sns.swarmplot(x="diabetes", y="heartRate", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>I picked a swarm plot because it allows me to visualize the distribution of a continuous variable, heartRate, across two levels of a binary variable, diabetes. By plotting diabetes on the x-axis and heartRate on the y-axis, I can compare the distribution of heart rates between individuals with and without diabetes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>It can be observed that individuals without diabetes have a higher heart rate compared to those with diabetes. This could indicate a potential relationship between diabetes and heart rate, where individuals with diabetes have a lower heart rate compared to those without diabetes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# <b>I picked a swarm plot because it allows me to visualize the distribution of a continuous variable, heartRate, across two levels of a binary variable, diabetes. By plotting diabetes on the x-axis and heartRate on the y-axis, I can compare the distribution of heart rates between individuals with and without diabetes.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
sns.boxenplot(x="TenYearCHD", y="BMI", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>By using a boxenplot, we can see whether there is a difference in the distribution of BMI between people who develop TenYearCHD and those who don't. If there is a significant difference, it suggests that BMI may be a risk factor for developing coronary heart disease. Additionally, we can see if there are any outliers or unusual patterns in the data that may warrant further investigation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>We can observe that the median BMI values of individuals with TenYearCHD = 0 is slightly higher than that of individuals with TenYearCHD = 1. This indicates that individuals with higher BMI are less likely to have CHD in the next 10 years.
#
# However, the interquartile range of BMI values is similar for both categories of TenYearCHD, indicating that there is a similar spread of BMI values for both categories. The outliers on the right side of the plot are individuals with a high BMI value who did not have CHD in the next 10 years, which might suggest that BMI alone is not a decisive factor for CHD. Further analysis, such as exploring the relationship between other variables and CHD, is necessary to draw more comprehensive conclusions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *Answer* Here
#
# <b>Overall, the boxenplot is a useful visualization tool for exploring the relationship between a continuous and categorical variable and can provide insights into potential risk factors for a health outcome like coronary heart disease.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
sns.jointplot(x="sysBP", y="diaBP", data=df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>The jointplot is a useful visualization tool for exploring the relationship between two continuous variables. It displays a scatter plot of the data points, along with the distribution of each variable on the x and y axes. This allows us to see the overall pattern of the data and any potential correlations between the two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>We can observe that there is a positive relationship between systolic and diastolic blood pressure, meaning that as systolic blood pressure increases, diastolic blood pressure also increases. The plot also shows the distribution of each variable through the histograms on either side of the plot. This information can be useful in understanding the distribution of the two variables and any potential outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
# <b>By using a jointplot, we can easily see whether there is a linear relationship between "sysBP" and "diaBP." If there is a positive correlation between the two variables, it suggests that as "sysBP" increases, so does "diaBP." Conversely, if there is a negative correlation, it suggests that as "sysBP" increases, "diaBP" decreases. Additionally, we can see the distribution of both variables, which may provide insights into potential risk factors or outliers.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

cor = df.corr()
plt.figure(figsize = (20,10))
sns.heatmap(cor,annot = True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# <b>Seaborns Heatmap chat is a great chart to visualize the correlation between multiple column in one go.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# <b>There is no correlation

# %%
dff = df.groupby('education').size()

# Make the plot with pandas
dff.plot(kind='pie', subplots=True, figsize=(8, 8),cmap="crest", autopct='%1.1f%%')
plt.title("Pie Chart of Education")
plt.show()

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()
cat_col = df.select_dtypes(include = 'object').columns
for i in cat_col:
  df[i] = enc.fit_transform(df[i])

# %%
df.dtypes
# Out:
# id                   int64
# age                  int64
# education          float64
# sex                  int64
# is_smoking           int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, recall_score, precision_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

# %%
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
X = df.drop(["TenYearCHD","id"], axis=1)
y = df["TenYearCHD"]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Define the classifiers to use
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "XGBOOST": XGBClassifier(),
    "Naive Bayes": GaussianNB()
}

# Define a dataframe to store the results
results_df1 = pd.DataFrame(columns=["Accuracy", "Recall", "Precision", "F1 Score", "Confusion Matrix"])

# Loop through each classifier and evaluate its performance
for name, clf in classifiers.items():
    # Fit the model to the training data
    clf.fit(X_train, y_train)
    
    # Make predictions on the test data
    y_pred = clf.predict(X_test)
    
    # Calculate evaluation metrics
    accuracy = clf.score(X_test, y_test)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = 2 * (precision_score(y_test, y_pred) * recall) / (precision_score(y_test, y_pred) + recall)
    cm = confusion_matrix(y_test, y_pred)
    
    # Add the results to the dataframe
    results_df1.loc[name] = [accuracy, recall, precision,f1, cm]

# Print the results dataframe
results_df1
# Out:
#                      Accuracy    Recall  Precision  F1 Score  \
# Logistic Regression  0.848692  0.043796   0.750000  0.082759
# Decision Tree        0.755404  0.204380   0.208955  0.206642
# Random Forest        0.838453  0.058394   0.380952  0.101266
# K-Nearest Neighbors  0.833902  0.116788   0.390244  0.179775
# XGBOOST              0.829352  0.138686   0.372549  0.202128
# Naive Bayes          0.815700  0.218978   0.352941  0.270270
#
#                             Confusion Matrix
# Logistic Regression     [[740, 2], [131, 6]]
# Decision Tree        [[636, 106], [109, 28]]
# Random Forest          [[729, 13], [129, 8]]
# K-Nearest Neighbors   [[717, 25], [121, 16]]
# XGBOOST               [[710, 32], [118, 19]]
# Naive Bayes           [[687, 55], [107, 30]]

# %%
for i in range(len(results_df1['Confusion Matrix'])):
  print(results_df1['Confusion Matrix'].index[i])
  sns.heatmap(results_df1['Confusion Matrix'][i],annot = True)
  plt.show()
# Out:
# Logistic Regression
# Decision Tree
# Random Forest
# K-Nearest Neighbors
# XGBOOST
# Naive Bayes

# %%
results_df1
# Out:
#                      Accuracy    Recall  Precision  F1 Score  \
# Logistic Regression  0.848692  0.043796   0.750000  0.082759
# Decision Tree        0.755404  0.204380   0.208955  0.206642
# Random Forest        0.838453  0.058394   0.380952  0.101266
# K-Nearest Neighbors  0.833902  0.116788   0.390244  0.179775
# XGBOOST              0.829352  0.138686   0.372549  0.202128
# Naive Bayes          0.815700  0.218978   0.352941  0.270270
#
#                             Confusion Matrix
# Logistic Regression     [[740, 2], [131, 6]]
# Decision Tree        [[636, 106], [109, 28]]
# Random Forest          [[729, 13], [129, 8]]
# K-Nearest Neighbors   [[717, 25], [121, 16]]
# XGBOOST               [[710, 32], [118, 19]]
# Naive Bayes           [[687, 55], [107, 30]]

# %%
results_df1['Accuracy'].plot(kind = 'bar')
plt.show()

# %%
results_df1['Recall'].plot(kind = 'bar')
plt.show()

# %%
results_df1['Precision'].plot(kind = 'bar')
plt.show()

# %% [markdown]
# ## **Conclusions**:
#
# <b>Logistic Regression, Decision Tree, Random Forest, K-Nearest Neighbors, XGBOOST, and Naive Bayes. These models were evaluated based on their accuracy, recall, precision, and F1-score. Additionally, the confusion matrix was also used to present the true positive (TP), false positive (FP), true negative (TN), and false negative (FN) values.
#
# The logistic regression model achieved the highest accuracy of 0.849, but with low recall of 0.044. The decision tree model had a lower accuracy of 0.755 but a higher recall of 0.204, implying that it was better at identifying true positives. However, its precision was low at 0.209, indicating that it was not very good at avoiding false positives.
#
# The Random Forest model had a relatively high accuracy of 0.838 but a low recall of 0.058. The K-Nearest Neighbors model achieved an accuracy of 0.834, with a recall of 0.117 and precision of 0.39. XGBOOST had an accuracy of 0.829 with a recall of 0.139 and precision of 0.373. Finally, Naive Bayes achieved an accuracy of 0.816 with a recall of 0.219 and precision of 0.353.
#
# In conclusion, the logistic regression model performed the best in terms of accuracy but had low recall, which means that it was not very good at identifying true positive cases. The decision tree model performed well in recall but had low precision, which means that it was not very good at avoiding false positives. The other models had a mix of strengths and weaknesses, and the choice of the best model would depend on the specific needs and constraints of the problem at hand.

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# <b>From the given results, it seems that the logistic regression model has the highest accuracy (0.848692) among all the models, although the recall (0.043796) is quite low. This means that the model has a high overall accuracy, but it may not be correctly identifying all the positive cases (i.e., people with heart disease).
#
# However, it's important to consider other metrics as well, such as precision, F1 score, and the confusion matrix. Based on these metrics, we can see that the logistic regression model has a relatively high precision (0.75), but a low F1 score (0.082759), indicating that it may not be the best model for predicting positive cases.
#
# The decision tree and random forest models have lower overall accuracy than the logistic regression model, but they have higher recall values (0.204380 and 0.058394, respectively), which suggests that they are better at correctly identifying positive cases. However, their precision and F1 scores are relatively low, which indicates that they may have a higher rate of false positives.
#
# The K-nearest neighbors and XGBOOST models have similar accuracy and recall values as the decision tree and random forest models, but they have slightly higher precision and F1 scores. However, their confusion matrices indicate a relatively high number of false negatives, which may affect their overall performance.
#
# Finally, the Naive Bayes model has a relatively low accuracy compared to the other models, but it has the highest recall value (0.218978) and F1 score (0.270270) among all the models. This suggests that it may be a good model for identifying positive cases.
#
# Overall, the choice of the best model depends on the specific requirements of the problem and the trade-offs between accuracy, recall, precision, and other metrics. In the case of predicting heart disease, we may want to prioritize models with high recall values to correctly identify positive cases, while also keeping false positives to a minimum. Based on these criteria, the decision tree, random forest, K-nearest neighbors, and XGBOOST models may be worth exploring further.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
